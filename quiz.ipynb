# %%
import pandas as pd
data1 = {
    '학번': [1001, 1002, 1003, 1004],
    '이름': ['김철수', '이영희', '박지수', '최민준']
}
df1 = pd.DataFrame(data1)

# df2 생성
data2 = {
    '학번': [1001, 1002, 1004],
    '국어': [85, 92, 78],
    '영어': [90, 80, 82],
    '수학': [80, 75, 95]
}
df2 = pd.DataFrame(data2)

# NaN 채우기 (지금은 없어도 형식상 넣음)
df1 = df1.fillna(0)
df2 = df2.fillna(0)
