# %%
import numpy as np
import pandas as pd

# mine=pd.Series([10,20,30],index=['korean','english','math'])
# friend=pd.Series([70,50,50], index=['korean','english','math'])
# merge=mine+friend
# print(merge)

# dic={"a":[1,3], "b":[1,2], "c":[2,4]}
# df=pd.DataFrame(dic)
# df
df=pd.DataFrame({"cluster":[1,1,2,1,2,3], "org":['a','a','h','c','d','w'],"time":[8,6,34,23,74,6]},display(df))
df = df.sort_values("time", ascending=False)
month_se=pd.Series(['1월','2월','3월','4월'])
income_se=pd.Series([9500,6200,6050,7000])
expense_se=pd.Series([5040,2350,2300,4800])
df=pd.DataFrame({"월": month_se, '수익':income_se,'지출':expense_se})
m_idx=np.argmax(income_se)
print("최대 수익이 발생한 월", month_se[m_idx])
print("동윤이네 상점 수입 합계{:,}".format(income_se.sum()))
print("동윤이네 상점의 지출 합계{:,}".format(expense_se.sum()))
# Out:
#     월    수익    지출
# 0  1월  9500  5040
# 1  2월  6200  2350
# 2  3월  6050  2300
# 3  4월  7000  4800
# 최대 수익이 발생한 월 1월
# 동윤이네 상점 수입 합계28,750
# 동윤이네 상점의 지출 합계14,490
